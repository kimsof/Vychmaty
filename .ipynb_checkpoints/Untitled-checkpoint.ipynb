# %% [markdown]
# ### Решить задачу:
# ### $ \left\{\begin{matrix}
# \Delta u = 0\\
# 0\leq x\leq 1, 0 \leq y \leq 1 \\
# u(0, y) = 1, u(1, y) = 1\\
# u(x, 0) = 1, u(x, 1) = 1\\
# \end{matrix}\right. $
#
# ### Разностная схема:
# # $ \frac{u_{m-1,l} - 2u_{m,l} + u_{m+1,l}}{h_{x}^{2}} + \frac{u_{m,l-1} - 2u_{m,l} + u_{m,l+1}}{h_{y}^{2}} = f $

# %%
import numpy as np
import pandas as ps
import matplotlib.pyplot as plt

def table(array, x, y):                 # для вывода таблицы с ответом
    return ps.DataFrame(array, y, x)

def plot(u, x, y):                      # для построения графиков
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1, projection='3d')
    x, y = np.meshgrid(x, y)
    #u = function(p)
    ax.plot_surface(x, y, u)
    plt.show()

class Parameters(object):               # параметры задачи
    pass
p = Parameters() 
p.x0 = -1                               # границы по х
p.xM = 1          
p.y0 = -1                               # границы по y
p.yL = 1          
p.h = 0.1                               # шаг по x
p.N = 15
p.tau = 1
p.f = 4                                 # неоднородность
p.M = int((p.xM - p.x0)/p.h)
p.L = int((p.yL - p.y0)/p.h)
p.x = np.linspace(p.x0, p.xM, p.M + 1)   
p.y = np.linspace(p.y0, p.yL, p.L + 1)

# граничные функции
def phi_0(y):
    return y**2
def phi_M(y):
    return y**2
def psi_0(x):
    return x**2
def psi_L(x):
    return x**2

# %%
# div grad u = f
# МПИ
def function_mpi(p):

    # u в начальном приближении = 0 везде, кроме границ
    u = np.zeros(((p.L + 1),(p.M + 1)))
    u[0] = psi_0(p.x)
    u[p.L] = psi_L(p.x)
    u.T[0] = phi_0(p.y)
    u.T[p.M] = phi_M(p.y)
    
    
    # Au = F
    A = np.zeros(((p.M + 1)*(p.L + 1), (p.M + 1)*(p.L + 1)))
    F = u  # F для u на границах (ниже дозаполнится)
    
    u = u.reshape((p.M + 1)*(p.L + 1))
    F = F.reshape((p.M + 1)*(p.L + 1))
    
    # для граничных u при y[0] А имеет только глав. диагональ = 1
    for i in range(0, (p.M + 1) + 1):
        A[i][i] = 1 
        
    
    for i in range(p.M + 2, (p.M - 1 + (p.L - 1)*(p.M + 1)) + 1):
        
        # для граничных u при x[0] и x[M] А имеет только глав. диагональ = 1
        if i % (p.M + 1) == 0 or (i - p.M) % (p.M + 1) == 0:
            A[i][i] = 1
            
        # для неграничных u
        else:
            A[i][i] = -4/p.h**2
            A[i][i - 1] = 1/p.h**2
            A[i][i + 1] = 1/p.h**2
            A[i][i - 1 - p.M] = 1/p.h**2
            A[i][i + 1 + p.M] = 1/p.h**2
            F[i] = p.f
            
    # для граничных u при y[L] А имеет только глав. диагональ = 1
    for i in range(p.L*(p.M + 1) - 1, (p.M + p.L*(p.M + 1)) + 1):
        A[i][i] = 1 
    
    # итерационный процесс
    for n in range(p.N + 1):
        u_new = u - p.tau*np.dot(A,u) + p.tau*F
        u_new = u_new.reshape(((p.L + 1),(p.M + 1)))
        u_new[0] = psi_0(p.x)
        u_new[p.L] = psi_L(p.x)
        u_new.T[0] = phi_0(p.y)
        u_new.T[p.M] = phi_M(p.y)
        u_new = u_new.reshape((p.M + 1)*(p.L + 1))
        u = u_new
        
    u = u.reshape(((p.L + 1),(p.M + 1)))
    return u

u_mpi = function_mpi(p)

# %%
table(u_mpi, p.x, p.y)
# Out:
#       -1.0          -0.9          -0.8          -0.7          -0.6  \
# -1.0  1.00  8.100000e-01  6.400000e-01  4.900000e-01  3.600000e-01
# -0.9  0.81  4.552598e+43 -6.208539e+43  5.008772e+43 -2.867130e+43
# -0.8  0.64 -6.208539e+43  8.364486e+43 -6.619599e+43  3.687938e+43
# -0.7  0.49  5.008772e+43 -6.619599e+43  5.085259e+43 -2.718679e+43
# -0.6  0.36 -2.867130e+43  3.687938e+43 -2.718679e+43  1.371892e+43
# -0.5  0.25  1.247651e+43 -1.549719e+43  1.085519e+43 -5.102368e+42
# -0.4  0.16 -4.230090e+42  5.008071e+42 -3.272596e+42  1.384347e+42
# -0.3  0.09  1.170260e+42 -1.313861e+42  8.073156e+41 -3.169807e+41
# -0.2  0.04 -2.394196e+41  2.366097e+41 -1.161864e+41  2.134219e+40
# -0.1  0.01  6.142271e+40 -6.736561e+40  4.849959e+40 -2.871169e+40
#  0.0  0.00  1.811832e+39 -1.487694e+40  2.321675e+40 -2.358704e+40
#  0.1  0.01  6.142271e+40 -6.736561e+40  4.849959e+40 -2.871169e+40
#  0.2  0.04 -2.394196e+41  2.366097e+41 -1.161864e+41  2.134219e+40
#  0.3  0.09  1.170260e+42 -1.313861e+42  8.073156e+41 -3.169807e+41
#  0.4  0.16 -4.230090e+42  5.008071e+42 -3.272596e+42  1.384347e+42
#  0.5  0.25  1.247651e+43 -1.549719e+43  1.085519e+43 -5.102368e+42
#  0.6  0.36 -2.867130e+43  3.687938e+43 -2.718679e+43  1.371892e+43
#  0.7  0.49  5.008772e+43 -6.619599e+43  5.085259e+43 -2.718679e+43
#  0.8  0.64 -6.208539e+43  8.364486e+43 -6.619599e+43  3.687938e+43
#  0.9  0.81  4.552598e+43 -6.208539e+43  5.008772e+43 -2.867130e+43
#  1.0  1.00  8.100000e-01  6.400000e-01  4.900000e-01  3.600000e-01
#
#               -0.5          -0.4          -0.3          -0.2          -0.1  \
# -1.0  2.500000e-01  1.600000e-01  9.000000e-02  4.000000e-02  1.000000e-02
# -0.9  1.247651e+43 -4.230090e+42  1.170260e+42 -2.394196e+41  6.142271e+40
# -0.8 -1.549719e+43  5.008071e+42 -1.313861e+42  2.366097e+41 -6.736561e+40
# -0.7  1.085519e+43 -3.272596e+42  8.073156e+41 -1.161864e+41  4.849959e+40
# -0.6 -5.102368e+42  1.384347e+42 -3.169807e+41  2.134219e+40 -2.871169e+40
# -0.5  1.753549e+42 -4.195468e+41  9.911517e+40  4.745999e+39  1.880066e+40
# div grad u = f
# linalg.solve
def function_solve(p):
    
    # Au = F
    A = np.zeros(((p.M + 1)*(p.L + 1), (p.M + 1)*(p.L + 1)))
    
    # F для u на границах (ниже дозаполнится)
    F = np.zeros(((p.L + 1),(p.M + 1)))
    F[0] = psi_0(p.x)
    F[p.L] = psi_L(p.x)
    F.T[0] = phi_0(p.y)
    F.T[p.M] = phi_M(p.y)
    F = F.reshape((p.M + 1)*(p.L + 1))
    
    # для граничных u при y[0] А имеет только глав. диагональ = 1
    for i in range(0, (p.M + 1) + 1):
        A[i][i] = 1 
    
    
    for i in range(p.M + 2, (p.M - 1 + (p.L - 1)*(p.M + 1)) + 1):
        # для граничных u при x[0] и x[M] А имеет только глав. диагональ = 1
        if i % (p.M + 1) == 0 or (i - p.M) % (p.M + 1) == 0:
            A[i][i] = 1
            
        # для неграничных u
        else:
            A[i][i] = -4/p.h**2
            A[i][i - 1] = 1/p.h**2
            A[i][i + 1] = 1/p.h**2
            A[i][i - 1 - p.M] = 1/p.h**2
            A[i][i + 1 + p.M] = 1/p.h**2
            F[i] = p.f
            
    # для граничных u при y[L] А имеет только глав. диагональ = 1
    for i in range(p.L*(p.M + 1) - 1, (p.M + p.L*(p.M + 1)) + 1):
        A[i][i] = 1 
    
    u =np.linalg.solve(A, F)
        
    u = u.reshape(((p.L + 1), (p.M + 1)))
    
    return u

u_solve = function_solve(p)

# %%
table(u_solve, p.x, p.y)
# Out:
#               -1.0  -0.9          -0.8  -0.7          -0.6  -0.5  -0.4  -0.3  \
# -1.0  1.000000e+00  0.81  6.400000e-01  0.49  3.600000e-01  0.25  0.16  0.09
# -0.9  8.100000e-01  0.62  4.500000e-01  0.30  1.700000e-01  0.06 -0.03 -0.10
# -0.8  6.400000e-01  0.45  2.800000e-01  0.13  1.776357e-15 -0.11 -0.20 -0.27
# -0.7  4.900000e-01  0.30  1.300000e-01 -0.02 -1.500000e-01 -0.26 -0.35 -0.42
# -0.6  3.600000e-01  0.17  8.022257e-16 -0.15 -2.800000e-01 -0.39 -0.48 -0.55
# -0.5  2.500000e-01  0.06 -1.100000e-01 -0.26 -3.900000e-01 -0.50 -0.59 -0.66
# -0.4  1.600000e-01 -0.03 -2.000000e-01 -0.35 -4.800000e-01 -0.59 -0.68 -0.75
# -0.3  9.000000e-02 -0.10 -2.700000e-01 -0.42 -5.500000e-01 -0.66 -0.75 -0.82
# -0.2  4.000000e-02 -0.15 -3.200000e-01 -0.47 -6.000000e-01 -0.71 -0.80 -0.87
# -0.1  1.000000e-02 -0.18 -3.500000e-01 -0.50 -6.300000e-01 -0.74 -0.83 -0.90
#  0.0  3.115218e-14 -0.19 -3.600000e-01 -0.51 -6.400000e-01 -0.75 -0.84 -0.91
#  0.1  1.000000e-02 -0.18 -3.500000e-01 -0.50 -6.300000e-01 -0.74 -0.83 -0.90
#  0.2  4.000000e-02 -0.15 -3.200000e-01 -0.47 -6.000000e-01 -0.71 -0.80 -0.87
#  0.7 -0.47 -0.50  ... -0.50 -0.47 -0.42 -0.35 -0.26 -1.500000e-01 -0.02
#  0.8 -0.32 -0.35  ... -0.35 -0.32 -0.27 -0.20 -0.11  5.257696e-16  0.13
#  0.9 -0.15 -0.18  ... -0.18 -0.15 -0.10 -0.03  0.06  1.700000e-01  0.30
#  1.0  0.04  0.01  ...  0.01  0.04  0.09  0.16  0.25  3.600000e-01  0.49
#
#                0.8   0.9           1.0
# -1.0  6.400000e-01  0.81  1.000000e+00
# -0.9  4.500000e-01  0.62  8.100000e-01
# -0.8  2.800000e-01  0.45  6.400000e-01
# -0.7  1.300000e-01  0.30  4.900000e-01
# -0.6 -3.194449e-15  0.17  3.600000e-01
# -0.5 -1.100000e-01  0.06  2.500000e-01
# -0.4 -2.000000e-01 -0.03  1.600000e-01
# -0.3 -2.700000e-01 -0.10  9.000000e-02
# -0.2 -3.200000e-01 -0.15  4.000000e-02
# -0.1 -3.500000e-01 -0.18  1.000000e-02
#  0.0 -3.600000e-01 -0.19 -1.645509e-15
#  0.1 -3.500000e-01 -0.18  1.000000e-02
#  0.2 -3.200000e-01 -0.15  4.000000e-02
#  0.3 -2.700000e-01 -0.10  9.000000e-02
#  0.4 -2.000000e-01 -0.03  1.600000e-01
#  0.5 -1.100000e-01  0.06  2.500000e-01
#  0.6  1.996456e-15  0.17  3.600000e-01
#  0.7  1.300000e-01  0.30  4.900000e-01
#  0.8  2.800000e-01  0.45  6.400000e-01
#  0.9  4.500000e-01  0.62  8.100000e-01
#  1.0  6.400000e-01  0.81  1.000000e+00
#
# [21 rows x 21 columns]

# %%
# численное решение
plot(u_solve, p.x, p.y)

# %%
# аналитическое решение

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, projection='3d')

x, y = np.meshgrid(p.x, p.y)
u = x**2 + y**2 - 1
ax.plot_surface(x, y, u)

plt.show()

# %%
M = 4
L = 4
h = 0.2
tau = 1
u = np.zeros(((L + 1),(M + 1)))
u[0] = np.ones(M + 1)
u[L] = np.ones(M + 1)
u.T[0] = np.ones(L + 1)
u.T[M] = np.ones(L + 1)
u = u.reshape((M + 1)*(L + 1))

A = np.zeros(((M + 1)*(L + 1), (M + 1)*(L + 1)))
F = np.zeros((M + 1)*(L + 1))
for i in range(0, (M + 1) + 1):
    A[i][i] = 1 
    F[i] = 1 #boundary

for i in range(M + 2, (M - 1 + (L - 1)*(M + 1)) + 1):
    if i % (M + 1) == 0 or (i + 1) % (M + 1) == 0:
        A[i][i] = 1
        F[i] = 1 #boundary
        
    else:
        A[i][i] = -4/h**2
        A[i][i - 1] = 1/h**2
        A[i][i + 1] = 1/h**2
        A[i][i - 1 - M] = 1/h**2
        A[i][i + 1 + M] = 1/h**2
        F[i] = 0 #f

for i in range(L*(M + 1) - 1, (M + L*(M + 1)) + 1):
    A[i][i] = 1 
    F[i] = 1 #boundary
    
for n in range(10):
    u_new = u - tau*np.dot(A,u) - tau*F
    u = u_new
p(u)
#u_new =
